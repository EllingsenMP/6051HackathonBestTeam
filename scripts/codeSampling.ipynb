# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('chatbot_tutor_50k_dataset.csv')

# %%
data.head()
# Out:
#            id    subject grade_level                 topic  \
# 0  conv_00000  chemistry        high           equilibrium
# 1  conv_00001    physics  elementary       simple machines
# 2  conv_00002    biology        high  inheritance patterns
# 3  conv_00003    biology      middle       genetics basics
# 4  conv_00004    biology  elementary            human body
#
#                                        student_input  \
# 0  I need help with my homework How does equilibr...
# 1  I have a science question How does simple mach...
# 2  I have a science question What is important to...
# 3  Can you explain this to me? Why is genetics ba...
# 4  I have a science question What is important to...
#
#                                       tutor_response     data_type  \
# 0  Equilibrium works according to chemical princi...  conversation
# 1  Simple machines works according to scientific ...  conversation
# 2  The most important thing about inheritance pat...  conversation
# ...

# %%
sample = data.sample(5000)
sample.to_csv('eduBotSample.csv')

# %%
sample['subject'].value_counts()
# Out:
# subject
# physics      1693
# chemistry    1673
# biology      1634
# Name: count, dtype: int64
